# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 6: Basics of data visualization

# %% [markdown]
# ## Lab work 6

# %% [markdown]
# #### Мета:
#
# * навчитися візуалізовувати дані в Python

# %% [markdown]
# ### Завдання:

# %%
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd
import seaborn as sns

# %%
np.random.seed(0)

df = pd.DataFrame(data={'a':np.random.randint(0, 100, 30),
                        'b':np.random.randint(0, 100, 30),
                        'c':np.random.randint(0, 100, 30)})
df.head()
# Out:
#     a   b   c
# 0  44  47  17
# 1  47  64  79
# 2  64  82   4
# 3  67  99  42
# 4  67  88  58

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
#  - перші 3 графіки візуалізувати, викорстовуючи значення із df
#  - останній це пряма пропорційність

# %%
fig = plt.figure(figsize=(15,8))

plt.subplot(2,2,1)
plt.plot(df['a'])
plt.subplot(2,2,2)
plt.plot(df['b'])
plt.subplot(2,2,3)
plt.plot(df['c'])
plt.subplot(2,2,4)
plt.plot(df.index,df.index)

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку

# %%
fig = plt.figure(figsize=(15,8))

plt.plot(df['a'])

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - використовуйте колонки `a` та `b`

# %%
fig = plt.figure(figsize=(15,8))

plt.subplot(2,1,1)
plt.plot(df['a'])
plt.subplot(2,1,2)
plt.plot(df['b'])

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - використовуйте колонки `a` та `b`

# %%
fig, axes = plt.subplots(figsize=(15,8))

axes.plot(df[['a', 'b']])
# Out:
# [<matplotlib.lines.Line2D at 0x9b6beb0>,
#  <matplotlib.lines.Line2D at 0x9b6bf70>]

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - використовуйте колонки `a` та `b`
# - задайте стиль 'darkgrid' за допомогою команди `sns.set_style`

# %%
fig, axes = plt.subplots(figsize=(15,8))

axes.plot(df[['a', 'b']])
sns.set_style('darkgrid')

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - для колонки `a` використайте червоний колір та лінію формату `-.`
#
# - для колонки `b` використайте помаранчевий колір та товщину `10`
#
# - для колонки `c` використайте жовтий колір та товщину `1` і маркер `o`

# %%
fig, axes = plt.subplots(figsize=(15,8))

axes.plot(df['a'], 'r-.')
axes.plot(df['b'], color='orange', linewidth=10)
axes.plot(df['c'], color='yellow', linewidth=1, marker='o')

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - і не забудьте про легенду :)

# %%
fig, axes = plt.subplots(3, figsize=(15,8))

axes[0].plot(df['a'], label="Line A")
axes[0].legend(loc=4)
axes[1].plot(df['b'], label="Line B")
axes[1].legend(loc=6)
axes[2].plot(df['c'])

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - використайте томатний колір та відстань між стовбцями 0.5

# %%
fig, axes = plt.subplots(figsize=(15,8))
x=df.index
y=df['a']
axes.bar(x, y, alpha=0.5, color="tomato", label='a')
axes.legend(loc=1)

# %% [markdown]
# Створити візуалізацію, аналогічно рисунку
# - добавте всі підписи та правильний маркер

# %%
fig, axes = plt.subplots(figsize=(20,8))

axes.plot(df['a'], marker='^')
plt.xticks(range(0,30))
plt.xlabel('This is the X Axis', size=20)
plt.ylabel('This is the Y Axis')
plt.title('This is the Title')
# Out:
# Text(0.5, 1.0, 'This is the Title')
